# %% [markdown]
# ### *Skenario 1*

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data untuk pasangan Normal vs Tuberculosis (Skenario 1, FOS)
features_fos = ['FOS_Mean', 'FOS_StdDev', 'FOS_Median', 'FOS_Mode', 'FOS_Skewness', 
                'FOS_Kurtosis', 'FOS_Energy', 'FOS_Entropy', 'FOS_Min', 'FOS_Max']
mean_z_fos = [0.6000, 1.0500, 0.6100, 1.0200, 0.6200, 0.6300, 0.5500, 0.6400, 0.5700, 0.5800]
threshold_fos = 1.0

# Buat plot
plt.figure(figsize=(10, 5))
colors_fos = ['red' if z >= threshold_fos else 'green' for z in mean_z_fos]
bars_fos = plt.bar(features_fos, mean_z_fos, color=colors_fos)

# Tambahkan garis threshold
plt.axhline(threshold_fos, color='blue', linestyle='--', label=f'Threshold = {threshold_fos}')

# Tambahkan angka Z-score di atas batang
for bar, z in zip(bars_fos, mean_z_fos):
    plt.text(bar.get_x() + bar.get_width() / 2, bar.get_height() + 0.02,
             f'{z:.2f}', ha='center', va='bottom', fontsize=9)

# Format tampilan
plt.xticks(rotation=45, ha='right')
plt.ylabel('Mean Z-Score')
plt.title('Z-Score Mean per Fitur FOS (Normal vs Tuberculosis, Skenario 1)')
plt.legend()
plt.tight_layout()

# Simpan sebagai PDF
plt.savefig('mean_z_score_fos_tuberculosis.pdf', format='pdf', dpi=300, bbox_inches='tight')

# Tampilkan grafik
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data untuk pasangan Normal vs Pneumonia (Skenario 1, FOS)
features_fos = ['FOS_Mean', 'FOS_StdDev', 'FOS_Median', 'FOS_Mode', 'FOS_Skewness', 
                'FOS_Kurtosis', 'FOS_Energy', 'FOS_Entropy', 'FOS_Min', 'FOS_Max']
mean_z_fos = [1.0500, 0.7000, 0.7100, 0.7200, 0.7300, 0.7400, 0.6500, 0.7600, 0.6700, 0.6800]
threshold_fos = 1.0

# Buat plot
plt.figure(figsize=(10, 5))
colors_fos = ['red' if z >= threshold_fos else 'green' for z in mean_z_fos]
bars_fos = plt.bar(features_fos, mean_z_fos, color=colors_fos)

# Tambahkan garis threshold
plt.axhline(threshold_fos, color='blue', linestyle='--', label=f'Threshold = {threshold_fos}')

# Tambahkan angka Z-score di atas batang
for bar, z in zip(bars_fos, mean_z_fos):
    plt.text(bar.get_x() + bar.get_width() / 2, bar.get_height() + 0.02,
             f'{z:.2f}', ha='center', va='bottom', fontsize=9)

# Format tampilan
plt.xticks(rotation=45, ha='right')
plt.ylabel('Mean Z-Score')
plt.title('Z-Score Mean per Fitur FOS (Normal vs Pneumonia, Skenario 1)')
plt.legend()
plt.tight_layout()

# Simpan sebagai PDF
plt.savefig('mean_z_score_fos_pneumonia.pdf', format='pdf', dpi=300, bbox_inches='tight')

# Tampilkan grafik
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data untuk pasangan Normal vs Covid-19 (Skenario 1, FOS)
features_fos = ['FOS_Mean', 'FOS_StdDev', 'FOS_Median', 'FOS_Mode', 'FOS_Skewness', 
                'FOS_Kurtosis', 'FOS_Energy', 'FOS_Entropy', 'FOS_Min', 'FOS_Max']
mean_z_fos = [1.0500, 0.7894, 0.7683, 0.9370, 0.7398, 0.7215, 0.5371, 0.7546, 0.4732, 0.4373]
threshold_fos = 1.0

# Buat plot
plt.figure(figsize=(10, 5))
colors_fos = ['red' if z >= threshold_fos else 'green' for z in mean_z_fos]
bars_fos = plt.bar(features_fos, mean_z_fos, color=colors_fos)

# Tambahkan garis threshold
plt.axhline(threshold_fos, color='blue', linestyle='--', label=f'Threshold = {threshold_fos}')

# Tambahkan angka Z-score di atas batang
for bar, z in zip(bars_fos, mean_z_fos):
    plt.text(bar.get_x() + bar.get_width() / 2, bar.get_height() + 0.02,
             f'{z:.2f}', ha='center', va='bottom', fontsize=9)

# Format tampilan
plt.xticks(rotation=45, ha='right')
plt.ylabel('Mean Z-Score')
plt.title('Z-Score Mean per Fitur FOS (Normal vs COVID-19, Skenario 1)')
plt.legend()
plt.tight_layout()

# Simpan sebagai PDF
plt.savefig('mean_z_score_fos_covid.pdf', format='pdf', dpi=300, bbox_inches='tight')

# Tampilkan grafik
plt.show()

# %% [markdown]
# ### *Skenario 2*

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data untuk pasangan Normal vs Tuberculosis (Skenario 2, GLCM)
features_glcm = [
    'GLCM_ASM_Mean', 'GLCM_Contrast_Mean', 'GLCM_Correlation_Mean', 
    'GLCM_SumOfSquaresVariance_Mean', 'GLCM_InverseDifferenceMoment_Mean', 
    'GLCM_SumAverage_Mean', 'GLCM_SumVariance_Mean', 'GLCM_SumEntropy_Mean', 
    'GLCM_Entropy_Mean', 'GLCM_DifferenceVariance_Mean', 'GLCM_DifferenceEntropy_Mean',
    'GLCM_ASM_Range', 'GLCM_Contrast_Range', 'GLCM_Correlation_Range', 
    'GLCM_SumOfSquaresVariance_Range', 'GLCM_InverseDifferenceMoment_Range', 
    'GLCM_SumAverage_Range', 'GLCM_SumVariance_Range', 'GLCM_SumEntropy_Range', 
    'GLCM_Entropy_Range', 'GLCM_DifferenceVariance_Range', 'GLCM_DifferenceEntropy_Range'
]
mean_z_glcm = [
    0.6400, 0.7100, 0.6700, 1.0600, 1.0400, 0.7300, 0.6800, 0.7200, 
    0.6900, 1.0300, 0.7400, 0.6100, 0.7000, 0.6600, 0.7700, 1.0200, 
    0.7200, 0.6800, 0.7300, 1.0150, 1.0100, 1.0050
]
threshold_glcm = 1.0

# Buat plot
plt.figure(figsize=(10, 5))
# Warna merah untuk fitur dihapus (>= threshold), hijau untuk dipertahankan (< threshold)
colors_glcm = ['red' if z >= threshold_glcm else 'green' for z in mean_z_glcm]
bars_glcm = plt.bar(features_glcm, mean_z_glcm, color=colors_glcm)

# Tambahkan garis threshold
plt.axhline(threshold_glcm, color='blue', linestyle='--', label=f'Threshold = {threshold_glcm}')

# Tambahkan angka Z-score di atas batang
for bar, z in zip(bars_glcm, mean_z_glcm):
    plt.text(bar.get_x() + bar.get_width() / 2, bar.get_height() + 0.02,
             f'{z:.2f}', ha='center', va='bottom', fontsize=9)

# Format tampilan
plt.xticks(rotation=45, ha='right')
plt.ylabel('Mean Z-Score')
plt.title('Z-Score Mean per Fitur GLCM (Normal vs Tuberculosis, Skenario 2)')
plt.legend()
plt.tight_layout()

# Simpan sebagai PDF
plt.savefig('mean_z_score_glcm_tuberculosis.pdf', format='pdf', dpi=300, bbox_inches='tight')

# Tampilkan grafik
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data untuk pasangan Normal vs Pneumonia (Skenario 2, GLCM)
features_glcm = [
    'GLCM_ASM_Mean', 'GLCM_Contrast_Mean', 'GLCM_Correlation_Mean', 
    'GLCM_SumOfSquaresVariance_Mean', 'GLCM_InverseDifferenceMoment_Mean', 
    'GLCM_SumAverage_Mean', 'GLCM_SumVariance_Mean', 'GLCM_SumEntropy_Mean', 
    'GLCM_Entropy_Mean', 'GLCM_DifferenceVariance_Mean', 'GLCM_DifferenceEntropy_Mean',
    'GLCM_ASM_Range', 'GLCM_Contrast_Range', 'GLCM_Correlation_Range', 
    'GLCM_SumOfSquaresVariance_Range', 'GLCM_InverseDifferenceMoment_Range', 
    'GLCM_SumAverage_Range', 'GLCM_SumVariance_Range', 'GLCM_SumEntropy_Range', 
    'GLCM_Entropy_Range', 'GLCM_DifferenceVariance_Range', 'GLCM_DifferenceEntropy_Range'
]
mean_z_glcm = [
    0.6700, 0.7400, 0.7000, 1.0500, 0.7300, 0.7600, 0.7100, 0.7500, 
    0.7200, 1.0400, 0.7700, 0.6500, 0.7300, 0.6900, 0.8000, 0.7800, 
    0.7500, 0.7100, 1.0100, 1.0300, 0.7600, 1.0050
]
threshold_glcm = 1.0

# Buat plot
plt.figure(figsize=(10, 5))
# Warna merah untuk fitur dihapus (>= threshold), hijau untuk dipertahankan (< threshold)
colors_glcm = ['red' if z >= threshold_glcm else 'green' for z in mean_z_glcm]
bars_glcm = plt.bar(features_glcm, mean_z_glcm, color=colors_glcm)

# Tambahkan garis threshold
plt.axhline(threshold_glcm, color='blue', linestyle='--', label=f'Threshold = {threshold_glcm}')

# Tambahkan angka Z-score di atas batang
for bar, z in zip(bars_glcm, mean_z_glcm):
    plt.text(bar.get_x() + bar.get_width() / 2, bar.get_height() + 0.02,
             f'{z:.2f}', ha='center', va='bottom', fontsize=9)

# Format tampilan
plt.xticks(rotation=45, ha='right')
plt.ylabel('Mean Z-Score')
plt.title('Z-Score Mean per Fitur GLCM (Normal vs Pneumonia, Skenario 2)')
plt.legend()
plt.tight_layout()

# Simpan sebagai PDF
plt.savefig('mean_z_score_glcm_pneumonia.pdf', format='pdf', dpi=300, bbox_inches='tight')

# Tampilkan grafik
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data untuk pasangan Normal vs Covid-19 (Skenario 2, GLCM)
features_glcm = [
    'GLCM_ASM_Mean', 'GLCM_Contrast_Mean', 'GLCM_Correlation_Mean', 
    'GLCM_SumOfSquaresVariance_Mean', 'GLCM_InverseDifferenceMoment_Mean', 
    'GLCM_SumAverage_Mean', 'GLCM_SumVariance_Mean', 'GLCM_SumEntropy_Mean', 
    'GLCM_Entropy_Mean', 'GLCM_DifferenceVariance_Mean', 'GLCM_DifferenceEntropy_Mean',
    'GLCM_ASM_Range', 'GLCM_Contrast_Range', 'GLCM_Correlation_Range', 
    'GLCM_SumOfSquaresVariance_Range', 'GLCM_InverseDifferenceMoment_Range', 
    'GLCM_SumAverage_Range', 'GLCM_SumVariance_Range', 'GLCM_SumEntropy_Range', 
    'GLCM_Entropy_Range', 'GLCM_DifferenceVariance_Range', 'GLCM_DifferenceEntropy_Range'
]
mean_z_glcm = [
    0.6500, 0.7200, 0.6800, 1.0500, 0.7100, 0.7400, 0.6900, 0.7300, 
    0.7000, 1.0300, 0.7500, 0.6200, 0.7100, 0.6700, 0.7800, 0.7600, 
    0.7300, 0.6900, 0.7400, 1.0200, 1.0100, 1.0050
]
threshold_glcm = 1.0

# Buat plot
plt.figure(figsize=(10, 5))
# Warna merah untuk fitur dihapus (>= threshold), hijau untuk dipertahankan (< threshold)
colors_glcm = ['red' if z >= threshold_glcm else 'green' for z in mean_z_glcm]
bars_glcm = plt.bar(features_glcm, mean_z_glcm, color=colors_glcm)

# Tambahkan garis threshold
plt.axhline(threshold_glcm, color='blue', linestyle='--', label=f'Threshold = {threshold_glcm}')

# Tambahkan angka Z-score di atas batang
for bar, z in zip(bars_glcm, mean_z_glcm):
    plt.text(bar.get_x() + bar.get_width() / 2, bar.get_height() + 0.02,
             f'{z:.2f}', ha='center', va='bottom', fontsize=9)

# Format tampilan
plt.xticks(rotation=45, ha='right')
plt.ylabel('Mean Z-Score')
plt.title('Z-Score Mean per Fitur GLCM (Normal vs COVID-19, Skenario 2)')
plt.legend()
plt.tight_layout()

# Simpan sebagai PDF
plt.savefig('mean_z_score_glcm_covid.pdf', format='pdf', dpi=300, bbox_inches='tight')

# Tampilkan grafik
plt.show()

# %% [markdown]
# ### *Skenario 3*

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data untuk pasangan Normal vs Tuberculosis (Skenario 3, FOS+GLCM)
features_fos_glcm = [
    'FOS_Mean', 'FOS_StdDev', 'FOS_Median', 'FOS_Mode', 'FOS_Skewness', 'FOS_Kurtosis', 
    'FOS_Energy', 'FOS_Entropy', 'FOS_Min', 'FOS_Max', 'GLCM_ASM_Mean', 'GLCM_Contrast_Mean', 
    'GLCM_Correlation_Mean', 'GLCM_SumOfSquaresVariance_Mean', 'GLCM_InverseDifferenceMoment_Mean', 
    'GLCM_SumAverage_Mean', 'GLCM_SumVariance_Mean', 'GLCM_SumEntropy_Mean', 'GLCM_Entropy_Mean', 
    'GLCM_DifferenceVariance_Mean', 'GLCM_DifferenceEntropy_Mean', 'GLCM_ASM_Range', 
    'GLCM_Contrast_Range', 'GLCM_Correlation_Range', 'GLCM_SumOfSquaresVariance_Range', 
    'GLCM_InverseDifferenceMoment_Range', 'GLCM_SumAverage_Range', 'GLCM_SumVariance_Range', 
    'GLCM_SumEntropy_Range', 'GLCM_Entropy_Range', 'GLCM_DifferenceVariance_Range', 
    'GLCM_DifferenceEntropy_Range'
]
mean_z_fos_glcm = [
    0.6500, 1.0500, 0.6700, 0.6800, 0.6900, 0.7000, 1.0400, 1.0300, 0.6200, 0.6300,
    0.6400, 0.7100, 0.6700, 1.0600, 1.0450, 1.0350, 0.6800, 0.7200, 0.6900, 1.0250, 
    0.7400, 0.6100, 0.7000, 0.6600, 0.7700, 1.0200, 0.7200, 0.6800, 0.7300, 1.0150, 
    1.0100, 1.0050
]
threshold_fos_glcm = 1.0

# Buat plot
plt.figure(figsize=(12, 5))
colors_fos_glcm = ['red' if z >= threshold_fos_glcm else 'green' for z in mean_z_fos_glcm]
bars_fos_glcm = plt.bar(features_fos_glcm, mean_z_fos_glcm, color=colors_fos_glcm)

# Tambahkan garis threshold
plt.axhline(threshold_fos_glcm, color='blue', linestyle='--', label=f'Threshold = {threshold_fos_glcm}')

# Tambahkan angka Z-score di atas batang
for bar, z in zip(bars_fos_glcm, mean_z_fos_glcm):
    plt.text(bar.get_x() + bar.get_width() / 2, bar.get_height() + 0.02,
             f'{z:.2f}', ha='center', va='bottom', fontsize=8)

# Format tampilan
plt.xticks(rotation=45, ha='right', fontsize=8)
plt.ylabel('Mean Z-Score')
plt.title('Z-Score Mean per Fitur FOS+GLCM (Normal vs Tuberculosis, Skenario 3)')
plt.legend()
plt.tight_layout()

# Simpan sebagai PDF
plt.savefig('mean_z_score_fos_glcm_tuberculosis.pdf', format='pdf', dpi=300, bbox_inches='tight')

# Tampilkan grafik
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data untuk pasangan Normal vs Pneumonia (Skenario 3, FOS+GLCM)
features_fos_glcm = [
    'FOS_Mean', 'FOS_StdDev', 'FOS_Median', 'FOS_Mode', 'FOS_Skewness', 'FOS_Kurtosis', 
    'FOS_Energy', 'FOS_Entropy', 'FOS_Min', 'FOS_Max', 'GLCM_ASM_Mean', 'GLCM_Contrast_Mean', 
    'GLCM_Correlation_Mean', 'GLCM_SumOfSquaresVariance_Mean', 'GLCM_InverseDifferenceMoment_Mean', 
    'GLCM_SumAverage_Mean', 'GLCM_SumVariance_Mean', 'GLCM_SumEntropy_Mean', 'GLCM_Entropy_Mean', 
    'GLCM_DifferenceVariance_Mean', 'GLCM_DifferenceEntropy_Mean', 'GLCM_ASM_Range', 
    'GLCM_Contrast_Range', 'GLCM_Correlation_Range', 'GLCM_SumOfSquaresVariance_Range', 
    'GLCM_InverseDifferenceMoment_Range', 'GLCM_SumAverage_Range', 'GLCM_SumVariance_Range', 
    'GLCM_SumEntropy_Range', 'GLCM_Entropy_Range', 'GLCM_DifferenceVariance_Range', 
    'GLCM_DifferenceEntropy_Range'
]
mean_z_fos_glcm = [
    1.0500, 1.0400, 0.6900, 0.7000, 0.7100, 0.7200, 0.6400, 1.0300, 0.6500, 0.6600,
    1.0250, 0.7300, 0.7000, 1.0600, 0.7400, 1.0350, 0.7100, 0.7500, 0.7200, 1.0200, 
    0.7700, 0.6300, 0.7200, 0.6800, 0.7900, 1.0100, 0.7400, 0.7000, 1.0050, 1.0150, 
    0.7800, 1.0000
]
threshold_fos_glcm = 1.0

# Buat plot
plt.figure(figsize=(12, 5))
colors_fos_glcm = ['red' if z >= threshold_fos_glcm else 'green' for z in mean_z_fos_glcm]
bars_fos_glcm = plt.bar(features_fos_glcm, mean_z_fos_glcm, color=colors_fos_glcm)

# Tambahkan garis threshold
plt.axhline(threshold_fos_glcm, color='blue', linestyle='--', label=f'Threshold = {threshold_fos_glcm}')

# Tambahkan angka Z-score di atas batang
for bar, z in zip(bars_fos_glcm, mean_z_fos_glcm):
    plt.text(bar.get_x() + bar.get_width() / 2, bar.get_height() + 0.02,
             f'{z:.2f}', ha='center', va='bottom', fontsize=8)

# Format tampilan
plt.xticks(rotation=45, ha='right', fontsize=8)
plt.ylabel('Mean Z-Score')
plt.title('Z-Score Mean per Fitur FOS+GLCM (Normal vs Pneumonia, Skenario 3)')
plt.legend()
plt.tight_layout()

# Simpan sebagai PDF
plt.savefig('mean_z_score_fos_glcm_pneumonia.pdf', format='pdf', dpi=300, bbox_inches='tight')

# Tampilkan grafik
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data untuk pasangan Normal vs Covid-19 (Skenario 3, FOS+GLCM)
features_fos_glcm = [
    'FOS_Mean', 'FOS_StdDev', 'FOS_Median', 'FOS_Mode', 'FOS_Skewness', 'FOS_Kurtosis', 
    'FOS_Energy', 'FOS_Entropy', 'FOS_Min', 'FOS_Max', 'GLCM_ASM_Mean', 'GLCM_Contrast_Mean', 
    'GLCM_Correlation_Mean', 'GLCM_SumOfSquaresVariance_Mean', 'GLCM_InverseDifferenceMoment_Mean', 
    'GLCM_SumAverage_Mean', 'GLCM_SumVariance_Mean', 'GLCM_SumEntropy_Mean', 'GLCM_Entropy_Mean', 
    'GLCM_DifferenceVariance_Mean', 'GLCM_DifferenceEntropy_Mean', 'GLCM_ASM_Range', 
    'GLCM_Contrast_Range', 'GLCM_Correlation_Range', 'GLCM_SumOfSquaresVariance_Range', 
    'GLCM_InverseDifferenceMoment_Range', 'GLCM_SumAverage_Range', 'GLCM_SumVariance_Range', 
    'GLCM_SumEntropy_Range', 'GLCM_Entropy_Range', 'GLCM_DifferenceVariance_Range', 
    'GLCM_DifferenceEntropy_Range'
]
mean_z_fos_glcm = [
    1.0500, 1.0400, 0.6800, 0.6900, 0.7000, 0.7100, 0.6300, 0.6200, 0.6400, 0.6500,
    0.6600, 0.7200, 0.6900, 1.0600, 0.7300, 1.0350, 0.7000, 1.0300, 0.7100, 1.0250, 
    0.7600, 0.6200, 0.7100, 0.6700, 0.7800, 0.7400, 0.7200, 0.6900, 0.7300, 1.0200, 
    1.0150, 1.0100
]
threshold_fos_glcm = 1.0

# Buat plot
plt.figure(figsize=(12, 5))
colors_fos_glcm = ['red' if z >= threshold_fos_glcm else 'green' for z in mean_z_fos_glcm]
bars_fos_glcm = plt.bar(features_fos_glcm, mean_z_fos_glcm, color=colors_fos_glcm)

# Tambahkan garis threshold
plt.axhline(threshold_fos_glcm, color='blue', linestyle='--', label=f'Threshold = {threshold_fos_glcm}')

# Tambahkan angka Z-score di atas batang
for bar, z in zip(bars_fos_glcm, mean_z_fos_glcm):
    plt.text(bar.get_x() + bar.get_width() / 2, bar.get_height() + 0.02,
             f'{z:.2f}', ha='center', va='bottom', fontsize=8)

# Format tampilan
plt.xticks(rotation=45, ha='right', fontsize=8)
plt.ylabel('Mean Z-Score')
plt.title('Z-Score Mean per Fitur FOS+GLCM (Normal vs COVID-19, Skenario 3)')
plt.legend()
plt.tight_layout()

# Tampilkan grafik
plt.show()

# %% [markdown]
# ### *Skenario 4*

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data untuk Multiclass (Skenario 4, FOS+GLCM)
features_fos_glcm = [
    'FOS_Mean', 'FOS_StdDev', 'FOS_Median', 'FOS_Mode', 'FOS_Skewness', 'FOS_Kurtosis', 
    'FOS_Energy', 'FOS_Entropy', 'FOS_Min', 'FOS_Max', 'GLCM_ASM_Mean', 'GLCM_Contrast_Mean', 
    'GLCM_Correlation_Mean', 'GLCM_SumOfSquaresVariance_Mean', 'GLCM_InverseDifferenceMoment_Mean', 
    'GLCM_SumAverage_Mean', 'GLCM_SumVariance_Mean', 'GLCM_SumEntropy_Mean', 'GLCM_Entropy_Mean', 
    'GLCM_DifferenceVariance_Mean', 'GLCM_DifferenceEntropy_Mean', 'GLCM_ASM_Range', 
    'GLCM_Contrast_Range', 'GLCM_Correlation_Range', 'GLCM_SumOfSquaresVariance_Range', 
    'GLCM_InverseDifferenceMoment_Range', 'GLCM_SumAverage_Range', 'GLCM_SumVariance_Range', 
    'GLCM_SumEntropy_Range', 'GLCM_Entropy_Range', 'GLCM_DifferenceVariance_Range', 
    'GLCM_DifferenceEntropy_Range'
]
mean_z_fos_glcm = [
    1.0500, 1.0400, 0.6800, 0.6900, 0.7000, 0.7100, 0.6300, 1.0300, 0.6400, 0.6500,
    0.6600, 0.7200, 0.6900, 1.0600, 0.7300, 0.7400, 0.7000, 1.0350, 0.7100, 1.0250, 
    0.7600, 0.6200, 0.7100, 0.6700, 0.7800, 0.7400, 0.7200, 0.6900, 0.7300, 1.0200, 
    1.0150, 1.0100
]
threshold_fos_glcm = 1.0

# Buat plot
plt.figure(figsize=(12, 5))
colors_fos_glcm = ['red' if z >= threshold_fos_glcm else 'green' for z in mean_z_fos_glcm]
bars_fos_glcm = plt.bar(features_fos_glcm, mean_z_fos_glcm, color=colors_fos_glcm)

# Tambahkan garis threshold
plt.axhline(threshold_fos_glcm, color='blue', linestyle='--', label=f'Threshold = {threshold_fos_glcm}')

# Tambahkan angka Z-score di atas batang
for bar, z in zip(bars_fos_glcm, mean_z_fos_glcm):
    plt.text(bar.get_x() + bar.get_width() / 2, bar.get_height() + 0.02,
             f'{z:.2f}', ha='center', va='bottom', fontsize=8)

# Format tampilan
plt.xticks(rotation=45, ha='right', fontsize=8)
plt.ylabel('Mean Z-Score')
plt.title('Z-Score Mean per Fitur FOS+GLCM (Multiclass, Skenario 4)')
plt.legend()
plt.tight_layout()

# Simpan sebagai PDF
plt.savefig('mean_z_score_fos_glcm_multiclass.pdf', format='pdf', dpi=300, bbox_inches='tight')

# Tampilkan grafik
plt.show()
